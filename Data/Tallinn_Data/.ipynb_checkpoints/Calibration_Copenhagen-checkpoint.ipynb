# %%
# Necessary installations
# pip install psycopg2
# pip install import-ipynb

# %%
# Import necessary libraries
import import_ipynb
import psycopg2
import pandas as pd
import numpy as np

# %%
# Import preday functions
from init__preday import *
# Out:
# importing Jupyter notebook from init__preday.ipynb
# ...

# %%
# Import bayesian optimization functions
#from init__bo import *

# %%
# Import synpop12 individual table

# Connect to the database
conn = psycopg2.connect(
    dbname="DTU_test",
    user="postgres",
    password="a6984852800",
    host="localhost",
    port="5432",
    options="-c search_path=synpop12"
)

# Set the schema and table names
schema_name = "synpop12"
table_name = "individual_dimitris"

# Query the table and store the result in a pandas dataframe
#query = f"SELECT * FROM {synpop12}.{individual_dimitris}"
query = f"SELECT * FROM {individual_dimitris}"

df = pd.read_sql_query(query, conn)

# Close the database connection
conn.close()

# Print the first few rows of the dataframe
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 19
#      15 table_name = "individual_dimitris"
#      17 # Query the table and store the result in a pandas dataframe
#      18 #query = f"SELECT * FROM {synpop12}.{individual_dimitris}"
# ---> 19 query = f"SELECT * FROM {individual_dimitris}"
#      21 df = pd.read_sql_query(query, conn)
#      23 # Close the database connection
#
# NameError: name 'individual_dimitris' is not defined

# %%
# Import Talin test files 
df_params = pd.read_csv("C:\\Users\\dzerz\\Desktop\\Talin_Python\\data_preday\\preday_params_complete_tours_modes_v3.csv")
df_od_weighted = pd.read_csv("C:\\Users\\dzerz\\Desktop\\Talin_Python\\data_preday\\tallin_od_weighted_coded.csv")
df_grid_def = pd.read_csv("C:\\Users\\dzerz\\Desktop\\Talin_Python\\data_preday\\tallinn_grid_def.csv")
df_mode_balance = pd.read_csv("C:\\Users\\dzerz\\Desktop\\Talin_Python\\data_preday\\tallinn_mode_balance.csv")
df_od_mask = pd.read_csv("C:\\Users\\dzerz\\Desktop\\Talin_Python\\data_preday\\tallinn_od_mask_coded.csv")
df_population_workers = pd.read_csv("C:\\Users\\dzerz\\Desktop\\Talin_Python\\data_preday\\tallinn_population_workers.csv")

# %%
df_params.head()
# Out:
#   model                        param  module  include    initial  lower_limit  \
# 0   dpb     local cons_travel = 1.85  preday     True   1.850000         -2.0
# 1   dpb     local beta_homemaker = 0  preday     True   0.000000          0.0
# 2   dpb  local beta_retired = -0.419  preday     True  -0.419000         -2.0
# 3   dpb  local beta_fulltime = 14.10  preday     True  17.169008         10.0
# 4   dpb      local beta_parttime = 0  preday     True   0.000000          0.0
#
#    upper_limit  provided_initial
# 0     2.000000             1.850
# 1     0.000000             0.000
# 2     2.000000            -0.419
# 3    19.169008            14.100
# 4     0.000000             0.000

# %%
dictionary = df_params.to_dict(orient='list')
print(dictionary)
# Out:
# {'model': ['dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dpb', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 'dps', 
# ...
